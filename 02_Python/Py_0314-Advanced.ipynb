# %%
class A:
  x = 1
  def y(self):
    print('y')

# %%
class B(A):
  pass

# %%
class C:
  def __init__(self):
    self.a = A()

  # 예외처리
  def __getattr__(self, x):
    return getattr(self.a, x)
    # print(x)

# %%
b = B()
b.x
# Out:
# 1

# %%
b.y()
# Out:
# y

# %%
c = C()
c.x # self.a.x (self.a = A())
# Out:
# 1

# %%
d = input()
# Out:
# 3

# %%
type(d)
# Out:
# str

# %%
a = -3
(a).__abs__()
# Out:
# 3

# %% [markdown]
# 문자열을 메소드화, 기본적으로 input()은 문자열이기도 함.

# %%
getattr(a, "__abs__")()
# Out:
# 3

# %%
t = input()
getattr(-1, t)()
# Out:
# __abs__
# 1

# %% [markdown]
# 파이썬의 추상화는 **상속**과 **metaclass**의 형태로 구현한다.

# %%
class A:
  pass

# %%
a = A()

# %%
a[0] # 부모에 기능이 없어서 error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-40c0f127717a> in <cell line: 0>()
# ----> 1 a[0] # 부모에 기능이 없어서 error
#
# TypeError: 'A' object is not subscriptable

# %%
class A:
  def __getitem__(self, x):
    print('x')

a = A()

# %%
a[0] # 연산자의 기능을 바꾼다.
# Out:
# x

# %% [markdown]
# ### 연산자 오버로딩(Operator Overloading)
#
# Sequence 데이터에서 가장 중요한 기능인데, 이것을 사용자가 구현을 안했으면 어떻게 되는가?
#
# 이 경우에는 **주의를 주도록 한다.**

# %%
class B:
  def __add__(self, x):
    print('not add')

b = B()
b + 3
# Out:
# not add

# %%
from collections.abc import Sequence

# %%
class C(Sequence):
  pass

# %%
c = C() # 조건이 안되면 실행도 못함
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-1ef1f2c22529> in <cell line: 0>()
# ----> 1 c = C()
#
# TypeError: Can't instantiate abstract class C with abstract methods __getitem__, __len__

# %%
from abc import abstractmethod, ABC

class D(ABC):
  @abstractmethod
  def t(self):
    pass

# %%
class E(D):
  pass

e = E() # 개발자가 핵심적인 기능을 구현하지 않았기에 경고를 줬다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-9b6ce849ff3e> in <cell line: 0>()
#       2   pass
#       3
# ----> 4 e = E() # 개발자가 핵심적인 기능을 구현하지 않았기에 경고를 줬다.
#
# TypeError: Can't instantiate abstract class E with abstract method t

# %%
# tensorflow에서 경고를 주는 방법, 원하는 기능이 없음
class F:
  def s(self):
    raise NotImplementedError

class T(F):
  pass

t = T()
t.s()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-50-a97e7c7eca50> in <cell line: 0>()
#       8
#       9 t = T()
# ---> 10 t.s()
#
# <ipython-input-50-a97e7c7eca50> in s(self)
#       2 class F:
#       3   def s(self):
# ----> 4     raise NotImplementedError
#       5
#       6 class T(F):
#
# NotImplementedError:

# %% [markdown]
# ### Iterator Protocol

# %%
from itertools import chain

t = chain([1,2,3],[4,5,6])
next(t)
# Out:
# 1

# %%
next(t), next(t), next(t), next(t), next(t)
# Out:
# (2, 3, 4, 5, 6)

# %%
from itertools import count

c = count()
next(c), next(c), next(c), next(c), next(c)
# Out:
# (0, 1, 2, 3, 4)

# %%
from itertools import cycle

c = cycle([1,2,3])
next(c), next(c), next(c), next(c), next(c)
# Out:
# (1, 2, 3, 1, 2)

# %%
from itertools import combinations, combinations_with_replacement, permutations

# 비복원 추출
t = combinations([1,2,3], 2)
next(t), next(t), next(t)
# Out:
# ((1, 2), (1, 3), (2, 3))

# %%
# 복원 추출
t = combinations_with_replacement([1,2,3], 2)
next(t), next(t), next(t)
# Out:
# ((1, 1), (1, 2), (1, 3))

# %%
# 순열
t = permutations([1,2,3], 2)
next(t), next(t), next(t)
# Out:
# ((1, 2), (1, 3), (2, 1))

# %%
from operator import add

add(2,4)
# Out:
# 6

# %%
import seaborn as sns

tips = sns.load_dataset('tips')

# %%
tips.total_bill.map(lambda x: x*1450)
# Out:
# 0      24635.5
# 1      14993.0
# 2      30464.5
# 3      34336.0
# 4      35655.5
#         ...
# 239    42093.5
# 240    39411.0
# 241    32871.5
# 242    25839.0
# 243    27231.0
# Name: total_bill, Length: 244, dtype: float64

# %%
from functools import reduce

reduce(lambda x,y:x+y, [1,2,3,4,5])
# Out:
# 15

# %%
list(map(lambda x,y:x+y, [1,2,3],[2,3,4]))
# Out:
# [3, 5, 7]

# %% [markdown]
# ### Decorator
#
# **ASPECT ORIENTED PROGRAMMING**
#
# 기존 함수에 기능을 추가하고 확장해주는 기능, 내부적으로 합성함수의 형태로 존재한다.

# %%
def x(m):
  def y(n):
    return m+n
  return y

x(3)(4)
# Out:
# 7

# %%
def xx(fun):
  def yy():
    print('aaa')
    fun()
    print('bbb')
  return yy

# %%
@xx
def t():
  print(t)

# %%
# 기능을 추가, function codinator
t()
# Out:
# aaa
# <function xx.<locals>.yy at 0x7ed4d5db5c60>
# bbb

# %%
xx(lambda: print('ttt'))()
# Out:
# aaa
# ttt
# bbb

# %%
# 어렵다,,, 함수형 패러다임에서는 사용할 수밖에 없다.

class A:
  @classmethod
  def t(cls):
    pass

class B:
  @staticmethod
  def t(cls):
    pass
