# %% [markdown]
# ## State Machine

# %% [markdown]
# [Intro to Pandas](https://pandas.pydata.org/docs/getting_started/index.html#intro-to-pandas) [Ploting](https://pythonplot.com/)
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3], [4,5,6])

# %%
plt.figure(); # 끝에 ;을 넣으면 return이 없다.(ipynb only)

# %%
plt.axes()
# Out:
# <Axes: >

# %%
# figure > axes
plt.figure()
plt.axes((0,0,.5,.5))
plt.axes((0.5,0.5,0.5,.5))
plt.axes((0,0.5,.5,.5))
# Out:
# <Axes: >

# %%
# plt.figure() # state machine이 자동적으로 생성
plt.axes((0,0,.5,.5))
# Out:
# <Axes: >

# %%
# axes > plot
plt.figure()
plt.axes((0,0,.5,.5))
plt.plot([1,2,3]) # 가장 가까운 axes 위에 생성
plt.axes((0.5,0.5,0.5,.5))
plt.grid(True)
plt.axes((0,0.5,.5,.5))
plt.plot([1,2,3])

# %%
plt.grid(True)

# %%
plt.figure()
plt.show()

# %%
plt.figure(facecolor='ivory', edgecolor='blue', figsize=(5,5))
plt.plot([1,2,3])

# %%
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# plt.figure(figsize=(5,5))
plt.axes((0, 0, .5, .5)) # 먼저 선언하면 기존 거 사용함
tips.boxplot(figsize=(5,5))
# Out:
# <Axes: >

# %%
plt.axes(polar=True)
# Out:
# <PolarAxes: >

# %%
plt.axes(label='AAA')
# Out:
# <Axes: label='AAA'>

# %%
plt.style.available # 전역변수 지정 가능
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# 가장 처음에 이걸 어떻게 설정해놓느냐에 따라 모든 그래프의 다자인이 바뀜
plt.style.use('seaborn-v0_8-ticks')

# %%
plt.plot([1,2,3])

# %%
with plt.xkcd():
    plt.plot([1,2,3]);
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# ...

# %%
tips.groupby('sex')['tip'].mean().plot.pie()
# Out:
# <ipython-input-121-8ec70e26a85c>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('sex')['tip'].mean().plot.pie()
# <Axes: ylabel='tip'>

# %%
plt.ylim([2.5, 3.5]) # 범위 왜곡을 통해 차이를 강조(y축 조작)
tips.groupby('sex')['tip'].mean().plot.bar()
# Out:
# <ipython-input-122-9e1ae1d3d5b3>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('sex')['tip'].mean().plot.bar()
# <Axes: xlabel='sex'>

# %% [markdown]
# ---

# %%
import pandas as pd

tips = tips[['total_bill', 'tip']]
tips.plot()
# Out:
# <Axes: >

# %%
tips.set_index('tip').plot.bar()
# Out:
# <Axes: xlabel='tip'>

# %%
tips = sns.load_dataset('tips')
tips.groupby('sex')['tip'].mean().plot.bar()
# Out:
# <ipython-input-125-109fb4139eda>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('sex')['tip'].mean().plot.bar()
# <Axes: xlabel='sex'>

# %%
tips.pivot_table(index='day', columns=['size'], values=['tip'], aggfunc='max')
# Out:
# <ipython-input-126-997985b3ccc1>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tips.pivot_table(index='day', columns=['size'], values=['tip'], aggfunc='max')
#        tip
# size     1     2     3     4     5    6
# day
# Thur  1.83  5.85   4.0  5.17  5.00  6.7
# Fri   1.92  4.30   3.0  4.73   NaN  NaN
# Sat   1.00  5.00  10.0  9.00  3.00  NaN
# Sun    NaN  5.65   4.0  6.50  5.14  5.0

# %%
# pd.plotting. (one-liner지만, 예쁘지 않고 통계적으로 의미해석이 어려움)

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns # 그래프 그리는 패키지

tips = sns.load_dataset('tips')

# %%
tips.boxplot() # pandas
# pd.plotting.boxplot(tips)
# Out:
# <Axes: >

# %%
sns.boxplot(x='sex', y='tip', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='tip', y='sex', data=tips, hue='smoker')
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
plt.style.use('ggplot')
plt.figure(figsize=(8,5))
sns.boxplot(x='sex', y='tip', data=tips, hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>
